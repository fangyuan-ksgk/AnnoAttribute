# %%
from src.utils import TreeNode
from src.attribute import build_conversation_attribute_tree, build_personality_attribute_tree

tree = build_conversation_attribute_tree()
tree.draw(figsize=(8,8))

tree = build_personality_attribute_tree()
tree.draw(figsize=(8,8))
